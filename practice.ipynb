# %%
from typing import Dict, TypedDict, List
from langgraph.graph import StateGraph,START,END

# %%
class AgentState(TypedDict):
    name : str
    value: List[int]

# %%
def calculate(state: AgentState) -> AgentState:
    """calculate the value"""
    total = sum(state['value'])
    state['name'] = f"hey there {state['name']} your value is {total}" 
    print(state)
    return state

# %%
graph = StateGraph(AgentState)

graph.add_node("calculate" , calculate)
graph.set_entry_point("calculate")
graph.set_finish_point("calculate")

app = graph.compile()

# %%
from IPython.display import Image, display
display(Image(app.get_graph().draw_mermaid_png()))

# %%
answer = app.invoke({
    "name" : "Junaid",
    "value" : [1,2],

})
print(answer)
# Out:
# {'name': 'hey there Junaid your value is 3', 'value': [1, 2]}
# {'name': 'hey there Junaid your value is 3', 'value': [1, 2]}
